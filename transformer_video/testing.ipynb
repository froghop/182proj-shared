# %%
import dataset

# %%
ds = dataset.Dataset()

ds.query()
# Out:
# [[<PIL.Image.Image image mode=1 size=16x16 at 0x7FF690D05CA0>,
#   <PIL.Image.Image image mode=1 size=16x16 at 0x7FF68E9AF3D0>,
#   <PIL.Image.Image image mode=1 size=16x16 at 0x7FF690D057C0>,
#   <PIL.Image.Image image mode=1 size=16x16 at 0x7FF690CFE4C0>,
#   <PIL.Image.Image image mode=1 size=16x16 at 0x7FF690D39CA0>,
#   <PIL.Image.Image image mode=1 size=16x16 at 0x7FF690D39EE0>,
#   <PIL.Image.Image image mode=1 size=16x16 at 0x7FF690D49D90>,
#   <PIL.Image.Image image mode=1 size=16x16 at 0x7FF690D42EE0>,
#   <PIL.Image.Image image mode=1 size=16x16 at 0x7FF68E9AF760>,
#   <PIL.Image.Image image mode=1 size=16x16 at 0x7FF68E9AF280>],
#  [<PIL.Image.Image image mode=1 size=16x16 at 0x7FF690D39790>,
#   <PIL.Image.Image image mode=1 size=16x16 at 0x7FF690D39C10>,
#   <PIL.Image.Image image mode=1 size=16x16 at 0x7FF690D1DD60>,
#   <PIL.Image.Image image mode=1 size=16x16 at 0x7FF690D090D0>,
#   <PIL.Image.Image image mode=1 size=16x16 at 0x7FF690D24E50>,
# ...
